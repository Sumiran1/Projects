# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as skl

# %%
#merging all the csvs then outputting a df which we can work with
path = r'C:\Users\sumis\Desktop\NBA SOPHOMORE SLUMP PROJECT'                    
all_files = glob.glob(os.path.join(path, "*.csv"))     
df_from_each_file = (pd.read_csv(file) for file in all_files)
rookie_merged_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
rookie_merged_df.head()
# Out:
#   Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Voting Voting.1  \
# 0       Rank                     Player        Age         Tm  First  Pts Won
# 1          1   Michael Jordan\jordami01         21        CHI   57.5     57.5
# 2          2  Hakeem Olajuwon\olajuha01         22        HOU   20.5     20.5
# 3       Rank                     Player        Age         Tm  First  Pts Won
# 4          1    Patrick Ewing\ewingpa01         23        NYK   36.0     36.0
#
#   Voting.2 Voting.3 Unnamed: 8 Per Game Per Game.1 Per Game.2 Per Game.3  \
# 0  Pts Max    Share          G       MP        PTS        TRB        AST
# 1       78    0.737         82     38.3       28.2        6.5        5.9
# 2       78    0.263         82     35.5       20.6       11.9        1.4
# 3  Pts Max    Share          G       MP        PTS        TRB        AST
# 4       78    0.462         50     35.4       20.0        9.0        2.0
#
# ...

# %%
#cleaning up the columns and removing redundancies from the dataframe
rookie_merged_df= rookie_merged_df.drop_duplicates()
rookie_merged_df= rookie_merged_df.rename(columns=rookie_merged_df.iloc[0])
rookie_merged_df= rookie_merged_df.drop(rookie_merged_df.index[0])

# %%
rookie_merged_df.head()
# Out:
#   Rank                     Player Age   Tm First Pts Won Pts Max  Share   G  \
# 1    1   Michael Jordan\jordami01  21  CHI  57.5    57.5      78  0.737  82
# 2    2  Hakeem Olajuwon\olajuha01  22  HOU  20.5    20.5      78  0.263  82
# 4    1    Patrick Ewing\ewingpa01  23  NYK  36.0    36.0      78  0.462  50
# 5    2  Xavier McDaniel\mcdanxa01  22  SEA  16.5    16.5      78  0.212  82
# 6    3      Karl Malone\malonka01  22  UTA  14.5    14.5      78  0.186  81
#
#      MP   PTS   TRB  AST  STL  BLK    FG%    3P%    FT%    WS  WS/48
# 1  38.3  28.2   6.5  5.9  2.4  0.8  0.515  0.173  0.845    14  0.213
# 2  35.5  20.6  11.9  1.4  1.2  2.7  0.538    NaN  0.613  10.2  0.168
# 4  35.4  20.0   9.0  2.0  1.1  2.1   .474   .000   .739   3.1   .084
# 5  33.0  17.1   8.0  2.4  1.2  0.5   .490   .200   .687   5.1   .091
# 6  30.6  14.9   8.9  2.9  1.3  0.5   .496   .000   .481   1.9   .036

# %%
names= rookie_merged_df['Player'].unique()
print(names)
# Out:
# ['Michael Jordan\\jordami01' 'Hakeem Olajuwon\\olajuha01'
#  'Patrick Ewing\\ewingpa01' 'Xavier McDaniel\\mcdanxa01'
#  'Karl Malone\\malonka01' 'Spud Webb\\webbsp01' 'Manute Bol\\bolma01'
#  'Charles Oakley\\oaklech01' 'Benoit Benjamin\\benjabe01'
#  'Chuck Person\\persoch01' 'Ron Harper\\harpero01'
#  'Mark Jackson\\jacksma01' 'Greg Anderson\\andergr01'
#  'Winston Garland\\garlawi01' 'Kenny Smith\\smithke01'
#  'Mitch Richmond\\richmmi01' 'Willie Anderson\\anderwi01'
#  'Chris Morris\\morrich01' 'David Robinson\\robinda01'
#  'Derrick Coleman\\colemde01' 'Lionel Simmons\\simmoli01'
#  'Dennis Scott\\scottde01' 'Dee Brown\\brownde01'
#  'Larry Johnson\\johnsla02' 'Dikembe Mutombo\\mutomdi01'
#  'Billy Owens\\owensbi01' "Shaquille O'Neal\\onealsh01"
#  'Alonzo Mourning\\mournal01' 'Chris Webber\\webbech01'
#  'Anfernee Hardaway\\hardaan01' 'Jamal Mashburn\\mashbja01'
#  'Grant Hill\\hillgr01' 'Jason Kidd\\kiddja01' 'Glenn Robinson\\robingl01'
# ...
